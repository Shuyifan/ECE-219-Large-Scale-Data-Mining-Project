# %% [markdown]
# # Project 2 Clustering

# %% [markdown]
# ## Data check

# %%
# Load data

import numpy as np
np.random.seed(42)
import random
random.seed(42)
from sklearn.datasets import fetch_20newsgroups

categories = ['comp.sys.ibm.pc.hardware', 'comp.graphics',
              'comp.sys.mac.hardware', 'comp.os.ms-windows.misc', 
              'rec.autos', 'rec.motorcycles',
              'rec.sport.baseball', 'rec.sport.hockey']
dataset = fetch_20newsgroups(subset='all', categories=categories,
shuffle=True, random_state=42)

# %%
np.unique(dataset.target)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])

# %%
dataset.target_names
# Out:
# ['comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey']

# %%
# making data binary label -> Ground truth
def get_labels(train_dataset):
    labels = []
    new_name = ['Computer Technology','Recreational Activity']

    for label in train_dataset.target:
        name = train_dataset.target_names[label]
        if name.startswith('comp'):
            labels.append(0)
        elif name.startswith('rec'):
            labels.append(1)
        else:
            print('Wrong type!')
    
    return labels, new_name

label, label_name = get_labels(dataset)

#check the new binary label
print(np.unique(label))
print(label_name)
# Out:
# [0 1]
# ['Computer Technology', 'Recreational Activity']

# %% [markdown]
# ## Question 1:
# Report the dimensions of the TF-IDF matrix you get

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

vec = CountVectorizer(min_df=3,stop_words='english')
data_vec = vec.fit_transform(dataset.data)

tfidf = TfidfTransformer()
data_tfidf = tfidf.fit_transform(data_vec)

# %%
# show time
print(data_tfidf.shape)
# Out:
# (7882, 27768)

# %% [markdown]
# ## Question 2:
# Report the contingency table of your clustering result.

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(data_tfidf)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#     n_clusters=2, n_init=30, n_jobs=1, precompute_distances='auto',
#     random_state=0, tol=0.0001, verbose=0)

# %%
from sklearn.metrics.cluster import contingency_matrix

#true_label = [int(x / 4) for x in dataset.target]

print(contingency_matrix(label, km.labels_))
# Out:
# [[   4 3899]
#  [1718 2261]]

# %% [markdown]
# ## Question 3:
# Report the 5 measures above for the K-means clustering results you get.

# %%
from sklearn.metrics.cluster import homogeneity_score,\
                                    completeness_score,\
                                    v_measure_score,\
                                    adjusted_rand_score,\
                                    adjusted_mutual_info_score

# %%
print("The homogeneity score is:", 
      homogeneity_score(label, km.labels_))
print("The completeness_score score is:", 
      completeness_score(label, km.labels_))
print("The V-measure score is:", 
      v_measure_score(label, km.labels_))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, km.labels_))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, km.labels_))
# Out:
# The homogeneity score is: 0.2535958928926043
# The completeness_score score is: 0.334815748824373
# The V-measure score is: 0.28860033608397917
# The adjusted Rand Index score is: 0.18076179588914554
# The adjusted mutual information score is: 0.25352755133060884

# %% [markdown]
# ## Question 4:
# Report the plot of the percent of variance the top r principle components can retain v.s. r, for r = 1 to 1000

# %%
from sklearn.decomposition import TruncatedSVD

r = 1000
svd = TruncatedSVD(1000)
svd.fit(data_tfidf)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=1000, n_iter=5,
#        random_state=None, tol=0.0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

ratio = svd.explained_variance_ratio_.cumsum()
x = np.array(range(1, 1001))

plt.plot(x, ratio)
plt.title('Percent of the Variance - Rank')
plt.xlabel('Rank')
plt.ylabel('Percent of the Variance')
# Out:
# Text(0, 0.5, 'Percent of the Variance')

# %% [markdown]
# ## Question 5:
# Let r be the dimension that we want to reduce the data to (i.e. n_components).
#
# Try r = 1,2,3,5,10,20,50,100,300, and plot the 5 measure scores v.s. r for both SVD and NMF.
#
# Report the best r choice for SVD and NMF respectively.
#
# Note: what is “best” after all? What if some measures contradict with each other? Here you are faced with this challenge that you need to decide which measure you value the most, and design your own standard of “best”. Please explain your standard and justify it.

# %% [markdown]
# ### SVD

# %%
# process data using svd
ranks = [1, 2, 3, 5, 10, 20, 50, 100, 300]
hs,cs,vs,ars,amis = [],[],[],[],[]
for rank in ranks:
    svd = TruncatedSVD(n_components=rank)
    data_svd_r = svd.fit_transform(data_tfidf)
    
    # apply k-means
    km.fit(data_svd_r)
    
    # calculate 5 scores
    hs.append(homogeneity_score(label,km.labels_))
    cs.append(completeness_score(label,km.labels_))
    vs.append(v_measure_score(label,km.labels_))
    ars.append(adjusted_rand_score(label,km.labels_))
    amis.append(adjusted_mutual_info_score(label,km.labels_))
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# <ipython-input-19-bd24dec65910> in <module>
#       7
#       8     # apply k-means
# ----> 9     km.fit(data_svd_r)
#      10
#      11     # calculate 5 scores
#
# NameError: name 'km' is not defined

# %%
# plot 
plt.plot(ranks, hs)
plt.plot(ranks, cs)
plt.plot(ranks, vs)
plt.plot(ranks, ars)
plt.plot(ranks, amis)
plt.title('5 scores on SVD')
plt.xlabel('Rank')
plt.ylabel('Scores')
plt.legend(labels = ['homogeneity','completeness',
                     'V_measure','Adjsuted rand','Adjusted mutual'])

# %%
# plot within rank = 50
plt.plot(ranks[:6], hs[:6])
plt.plot(ranks[:6], cs[:6])
plt.plot(ranks[:6], vs[:6])
plt.plot(ranks[:6], ars[:6])
plt.plot(ranks[:6], amis[:6])
plt.title('5 scores SVD (zoomed version)')
plt.xlabel('Rank')
plt.ylabel('Scores')
plt.legend(labels = ['homogeneity','completeness',
                     'V_measure','Adjsuted rand','Adjusted mutual'])

# %% [markdown]
# #### The best rank for SVD seems to be 2.

# %% [markdown]
# ### NMF

# %%
# process data using nmf
from sklearn.decomposition import NMF

ranks = [1, 2, 3, 5, 10, 20, 50, 100, 300]
hs_nmf,cs_nmf,vs_nmf,ars_nmf,amis_nmf = [],[],[],[],[]
for rank in ranks:
    nmf = NMF(n_components=rank)
    data_nmf_r = nmf.fit_transform(data_tfidf)
    
    # apply k-means
    km.fit(data_nmf_r)
    
    # calculate 5 scores
    hs_nmf.append(homogeneity_score(label,km.labels_))
    cs_nmf.append(completeness_score(label,km.labels_))
    vs_nmf.append(v_measure_score(label,km.labels_))
    ars_nmf.append(adjusted_rand_score(label,km.labels_))
    amis_nmf.append(adjusted_mutual_info_score(label,km.labels_))
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# <ipython-input-22-fa0c7ac6c1e2> in <module>
#       9
#      10     # apply k-means
# ---> 11     km.fit(data_nmf_r)
#      12
#      13     # calculate 5 scores
#
# NameError: name 'km' is not defined

# %%
# plot 
plt.plot(ranks, hs_nmf)
plt.plot(ranks, cs_nmf)
plt.plot(ranks, vs_nmf)
plt.plot(ranks, ars_nmf)
plt.plot(ranks, amis_nmf)
plt.title('5 scores on NMF')
plt.xlabel('Rank')
plt.ylabel('Scores')
plt.legend(labels = ['homogeneity','completeness',
                     'V_measure','Adjsuted rand','Adjusted mutual'])

# %%
# plot within 20
plt.plot(ranks[:6], hs_nmf[:6])
plt.plot(ranks[:6], cs_nmf[:6])
plt.plot(ranks[:6], vs_nmf[:6])
plt.plot(ranks[:6], ars_nmf[:6])
plt.plot(ranks[:6], amis_nmf[:6])
plt.title('5 scores on NMF')
plt.xlabel('Rank')
plt.ylabel('Scores')
plt.legend(labels = ['homogeneity','completeness',
                     'V_measure','Adjsuted rand','Adjusted mutual'])

# %% [markdown]
# #### The best rank for NMF seems to be 2 too.

# %% [markdown]
# ## Question 6:
# How do you explain the non-monotonic behavior of the measures as r increases?

# %% [markdown]
# ## Question 7:
# Visualize the clustering results for:
# - SVD with its best r
# - NMF with its best r

# %%
# reduce to 2-D using SVD
svd = TruncatedSVD(n_components=2)
data_svd_2 = svd.fit_transform(data_tfidf)
# reduce to 2-D using NMF
nmf = NMF(n_components=2)
data_nmf_2 = nmf.fit_transform(data_tfidf)

# %% [markdown]
# ### SVD

# %%
# visulizing svd
plt.figure(figsize=(10, 10))

#X_svd = km.fit_transform(data_svd_2)
km.fit(data_svd_2)
y_pred_svd = km.predict(data_svd_2)

plt.subplot(121)
plt.scatter(data_svd_2[:, 0], data_svd_2[:, 1], c=y_pred_svd)
plt.title("Predicted cluster (NMF)")

plt.subplot(122)
plt.scatter(data_svd_2[:, 0], data_svd_2[:, 1], c=label)
plt.title("Ground truth cluster (NMF)")
# Out:
# -------------------------------------------------------------
# NameError                   Traceback (most recent call last)
# <ipython-input-24-9da0f7803006> in <module>
#       3
#       4 #X_svd = km.fit_transform(data_svd_2)
# ----> 5 km.fit(data_svd_2)
#       6 y_pred_svd = km.predict(data_svd_2)
#       7
#
# NameError: name 'km' is not defined

# %% [markdown]
# ### NMF

# %%
plt.figure(figsize=(10, 10))

#X_nmf = km.fit_transform(data_nmf_2)
km.fit(data_nmf_2)
y_pred_nmf = km.predict(data_nmf_2)

plt.subplot(121)
plt.scatter(data_nmf_2[:, 0], data_nmf_2[:, 1], c=y_pred_nmf)
plt.title("Predicted cluster (NMF)")

plt.subplot(122)
plt.scatter(data_nmf_2[:, 0], data_nmf_2[:, 1], c=label)
plt.title("Ground truth cluster (NMF)")
# Out:
# Text(0.5,1,'Ground truth cluster (NMF)')

# %% [markdown]
# ## Question 8 and Question 10:
#
# ### Question 8
# Visulaize the **transformed** data as in part (a).
#
# ### Question 10
# Report the new clustering measures (except for the contingency matrix) for the clustering results of the transformed data.

# %%
def log_transform(data):
    data = np.array(data)
    norm1 = np.linalg.norm(data, ord=1, axis=1)
    log = np.log2(norm1 + 0.01) - np.log2(0.01)
    log.shape = (log.shape[0], 1)
    mul = np.tile(log, (1, data.shape[1]))
    data[data > 0] = 1
    data[data < 0] = -1
    data = np.multiply(data, mul)
    return data

# %% [markdown]
# ## SVD (Scalar)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X_norm_svd = scaler.fit_transform(data_svd_2)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_norm_svd)
y_pred_norm_svd = km.predict(X_norm_svd)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_norm_svd[:, 0], X_norm_svd[:, 1], c=y_pred_norm_svd)
plt.title("Predicted cluster (SVD with Scaling)")

plt.subplot(122)
plt.scatter(X_norm_svd[:, 0], X_norm_svd[:, 1], c=label)
plt.title("Ground truth cluster (SVD with Scaling)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_svd))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_svd))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_svd))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_svd))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_svd))
# Out:
# The homogeneity score is: 0.2321640238896215
# The completeness_score score is: 0.2598894767663734
# The V-measure score is: 0.24524563533115648
# The adjusted Rand Index score is: 0.2523251622394887
# The adjusted mutual information score is: 0.23209372528174993
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Logarithm Transformation)

# %%
from sklearn.cluster import KMeans

X_logTrans_svd = log_transform(data_svd_2)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_logTrans_svd)
y_pred_norm_svd = km.predict(X_logTrans_svd)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_logTrans_svd[:, 0], X_logTrans_svd[:, 1], c=y_pred_norm_svd)
plt.title("Predicted cluster (SVD with Logarithm Transformation)")

plt.subplot(122)
plt.scatter(X_logTrans_svd[:, 0], X_logTrans_svd[:, 1], c=label)
plt.title("Ground truth cluster (SVD with Logarithm Transformation)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_svd))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_svd))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_svd))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_svd))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_svd))
# Out:
# The homogeneity score is: 0.6103717785911414
# The completeness_score score is: 0.6103342730274361
# The V-measure score is: 0.6103530252331192
# The adjusted Rand Index score is: 0.7173615344976553
# The adjusted mutual information score is: 0.6102986012138975
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Scaling + Logarithm Transformation)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X_norm_svd = scaler.fit_transform(data_svd_2)
X_norm_logTransorm = log_transform(X_norm_svd)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_norm_logTransorm)
y_pred_norm_svd = km.predict(X_norm_logTransorm)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_norm_logTransorm[:, 0], X_norm_logTransorm[:, 1], c=y_pred_norm_svd)
plt.title("Predicted cluster (SVD with Scaling + Logarithm Transformation)")

plt.subplot(122)
plt.scatter(X_norm_logTransorm[:, 0], X_norm_logTransorm[:, 1], c=label)
plt.title("Ground truth cluster (SVD with Scaling + Logarithm Transformation)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_svd))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_svd))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_svd))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_svd))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_svd))
# Out:
# The homogeneity score is: 7.786740831065591e-05
# The completeness_score score is: 7.803769820085726e-05
# The V-measure score is: 7.795246025480442e-05
# The adjusted Rand Index score is: -7.722450718525936e-06
# The adjusted mutual information score is: -1.367581383814243e-05
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Logarithm Transformation + Scaling)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

X_logTrans_svd = log_transform(data_svd_2)
X_logTransform_norm = scaler.fit_transform(X_logTrans_svd)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_logTransform_norm)
y_pred_norm_svd = km.predict(X_logTransform_norm)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_logTransform_norm[:, 0], X_logTransform_norm[:, 1], c=y_pred_norm_svd)
plt.title("Predicted cluster (SVD with Logarithm Transformation + Scaling)")

plt.subplot(122)
plt.scatter(X_logTransform_norm[:, 0], X_logTransform_norm[:, 1], c=label)
plt.title("Ground truth cluster (SVD with Logarithm Transformation + Scaling)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_svd))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_svd))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_svd))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_svd))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_svd))
# Out:
# The homogeneity score is: 0.6103717785911414
# The completeness_score score is: 0.6103342730274361
# The V-measure score is: 0.6103530252331192
# The adjusted Rand Index score is: 0.7173615344976553
# The adjusted mutual information score is: 0.6102986012138975
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### NMF (Scalar)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X_norm_nmf = scaler.fit_transform(data_nmf_2)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_norm_nmf)
y_pred_norm_nmf = km.predict(X_norm_nmf)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_norm_nmf[:, 0], X_norm_nmf[:, 1], c=y_pred_norm_nmf)
plt.title("Predicted cluster (nmf with Scaling)")

plt.subplot(122)
plt.scatter(X_norm_nmf[:, 0], X_norm_nmf[:, 1], c=label)
plt.title("Ground truth cluster (nmf with Scaling)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_nmf))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_nmf))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_nmf))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_nmf))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_nmf))
# Out:
# The homogeneity score is: 0.6828038321574016
# The completeness_score score is: 0.6856459752144646
# The V-measure score is: 0.6842219522524521
# The adjusted Rand Index score is: 0.7734426774605906
# The adjusted mutual information score is: 0.6827747927166996
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Logarithm Transformation)

# %%
from sklearn.cluster import KMeans

X_logTrans_nmf = log_transform(data_nmf_2)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_logTrans_nmf)
y_pred_norm_nmf = km.predict(X_logTrans_nmf)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_logTrans_nmf[:, 0], X_logTrans_nmf[:, 1], c=y_pred_norm_nmf)
plt.title("Predicted cluster (nmf with Logarithm Transformation)")

plt.subplot(122)
plt.scatter(X_logTrans_nmf[:, 0], X_logTrans_nmf[:, 1], c=label)
plt.title("Ground truth cluster (nmf with Logarithm Transformation)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_nmf))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_nmf))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_nmf))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_nmf))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_nmf))
# Out:
# The homogeneity score is: 0.15982372391635244
# The completeness_score score is: 0.25553831329245047
# The V-measure score is: 0.19665294935546612
# The adjusted Rand Index score is: 0.08743433926527591
# The adjusted mutual information score is: 0.1597467880358707
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Scaling + Logarithm Transformation)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
X_norm_nmf = scaler.fit_transform(data_nmf_2)
X_norm_logTransorm = log_transform(X_norm_nmf)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_norm_logTransorm)
y_pred_norm_nmf = km.predict(X_norm_logTransorm)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_norm_logTransorm[:, 0], X_norm_logTransorm[:, 1], c=y_pred_norm_nmf)
plt.title("Predicted cluster (nmf with Scaling + Logarithm Transformation)")

plt.subplot(122)
plt.scatter(X_norm_logTransorm[:, 0], X_norm_logTransorm[:, 1], c=label)
plt.title("Ground truth cluster (nmf with Scaling + Logarithm Transformation)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_nmf))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_nmf))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_nmf))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_nmf))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_nmf))
# Out:
# The homogeneity score is: 0.5003714097749817
# The completeness_score score is: 0.5028379358017073
# The V-measure score is: 0.5016016406442226
# The adjusted Rand Index score is: 0.598108673811804
# The adjusted mutual information score is: 0.5003256685579902
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ### SVD (Logarithm Transformation + Scaling)

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

X_logTrans_nmf = log_transform(data_nmf_2)
X_logTransform_norm = scaler.fit_transform(X_logTrans_nmf)
km = KMeans(n_clusters=2, max_iter=1000, n_init=30, random_state=0)
km.fit(X_logTransform_norm)
y_pred_norm_nmf = km.predict(X_logTransform_norm)

plt.figure(figsize=(10, 10))

plt.subplot(121)
plt.scatter(X_logTransform_norm[:, 0], X_logTransform_norm[:, 1], c=y_pred_norm_nmf)
plt.title("Predicted cluster (nmf with Logarithm Transformation + Scaling)")

plt.subplot(122)
plt.scatter(X_logTransform_norm[:, 0], X_logTransform_norm[:, 1], c=label)
plt.title("Ground truth cluster (nmf with Logarithm Transformation + Scaling)")

print("The homogeneity score is:", 
      homogeneity_score(label, y_pred_norm_nmf))
print("The completeness_score score is:", 
      completeness_score(label, y_pred_norm_nmf))
print("The V-measure score is:", 
      v_measure_score(label, y_pred_norm_nmf))
print("The adjusted Rand Index score is:", 
      adjusted_rand_score(label, y_pred_norm_nmf))
print("The adjusted mutual information score is:", 
      adjusted_mutual_info_score(label, y_pred_norm_nmf))
# Out:
# The homogeneity score is: 0.1620508178713641
# The completeness_score score is: 0.25948360771117934
# The V-measure score is: 0.19950698354326848
# The adjusted Rand Index score is: 0.08788544110163567
# The adjusted mutual information score is: 0.1619740858548134
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/cluster/supervised.py:732: FutureWarning: The behavior of AMI will change in version 0.22. To match the behavior of 'v_measure_score', AMI will use average_method='arithmetic' by default.
#   FutureWarning)

# %% [markdown]
# ## Question 9:
#  Can you justify why the “logarithm transformation” may improve the clustering results?
